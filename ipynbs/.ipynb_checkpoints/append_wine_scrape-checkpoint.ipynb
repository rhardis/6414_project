# %%
from bs4 import BeautifulSoup
from multiprocessing.dummy import Pool
import os
import shutil
import time
import requests
import re
import json
import glob
import unidecode
import pandas as pd
import numpy as np

# %%
BASE_URL = 'http://www.winemag.com/?s=&drink_type=wine&page={0}'
session = requests.Session()
HEADERS = {
    'user-agent': ('Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/48.0.2564.109 Safari/537.36')
}
DATA_DIR = 'data'
FILENAME = 'winemag-data'

# %%
def convert_to_ascii(wine_name):
    new_string = unidecode.unidecode(wine_name)
    return new_string
    

def scrape_page(wine_name):
    time.sleep(.5)
    formatted_wine_name = wine_name.replace('\'','')
    formatted_wine_name = formatted_wine_name.replace('(','')
    formatted_wine_name = formatted_wine_name.replace(')','')

    formatted_wine_name = formatted_wine_name.replace(' ','-').lower()
    formatted_wine_name = formatted_wine_name.replace('--','-')
    
    page_url = 'https://www.winemag.com/buying-guide/{}/'.format(formatted_wine_name)
    
    #print(page_url)
    
    retry_count = 0

    try:
        response = session.get(page_url, headers=HEADERS)
    except:
        print('Not working: {}'.format(page_url))
        return ''

    soup = BeautifulSoup(response.content, 'html.parser')
    txt = soup.get_text().replace('\n','')
    
    return txt

def get_abv(txt):
    try:
        abv_txt = re.findall(r'(?<=Alcohol)(.*)(?=%)', txt)[0]
        abv = float(re.findall(r'[0-9]+.?[0-9]+', abv_txt)[0])
    except IndexError:
        abv = np.nan
    return abv

def get_bottlesize(txt):    
    try:
        bottlesize_txt = re.findall(r'(?<=Bottle Size)(.*)(?=ml)', txt)[0]
        bottlesize = float(re.findall(r'[0-9]+',bottlesize_txt)[0])
    except IndexError:
        bottlesize = np.nan
    return bottlesize

def get_category(txt):
    try:
        importer = re.findall(r'(Importer\S)',txt)
        if importer:
            search_string = r'(?<=mlCategory)(.*)(?={})'.format(importer[0])
            category = re.findall(search_string, txt)[0]
        else:
            category = re.findall(r'(?<=mlCategory)(.*)(?=Date Published)', txt)[0]
    except IndexError:
        category = 'no_category'
    
    return category

def get_importer(txt):
    importer = re.findall(r'(Importer\S)',txt)
    if importer:
        search_string = r'(?<=Importer)(.*)(?=Date Published)'
        too_much_text = re.findall(search_string, txt)[0]
        importer_name = re.findall(r'(?<=Importer)(.*)$', too_much_text)[0]
    else:
        importer_name = 'not_imported'
        
    return importer_name

# %%
df = pd.read_csv(os.path.join('..','datasets','winemag-data-130k-v2.csv'))
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
#df = df.merge(df.title.apply(lambda s: pd.Series({'abv': scrape_page(x), 'feature2':s-1})), left_index=True, right_index=True)

# %%
length = len(df)
df = df.iloc[:length,:]
df['title'] = df.title.apply(lambda x: convert_to_ascii(x))

num = 100

# %%
odf = df.iloc[:num,:]
odf['page_txt'] = odf.title.apply(lambda x: scrape_page(x))
if True:
    odf2 = odf.copy(deep=True)
    odf2['abv'] = odf2.page_txt.apply(lambda x: get_abv(x))
    odf2['bottle_size'] = odf2.page_txt.apply(lambda x: get_bottlesize(x))
    odf2['category'] = odf2.page_txt.apply(lambda x: get_category(x))
    odf2['importer'] = odf2.page_txt.apply(lambda x: get_importer(x))
    odf2['importer'] = odf2.importer.apply(lambda x: convert_to_ascii(x))

if 'page_txt' in odf2.columns:
    print(odf2.columns)
    odf2.drop('page_txt', axis=1, inplace=True)

odf2.to_csv(os.path.join('..','datasets','sectional_scrape.csv'), index=False)
odf2.tail()
# Out:
# C:\Users\Richard Hardis\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'page_txt', 'abv', 'bottle_size', 'category',
#        'importer'],
#       dtype='object')
#    country                                        description  \
# 95  France  This is a dense wine, packed with both tannins...
# 96  France  The wine comes from one of the cru estates fol...
# 97      US  A wisp of bramble extends a savory tone from n...
# 98   Italy  Forest floor, menthol, espresso, cranberry and...
# 99      US  This blends 20% each of all five red-Bordeaux ...
#
#                     designation  points  price    province  \
# 95                          NaN      88   20.0  Beaujolais
# 96                          NaN      88   18.0  Beaujolais
# 97               Ingle Vineyard      88   20.0    New York
# 98                 Dono Riserva      88   30.0     Tuscany
# 99  Intreccio Library Selection      88   75.0  California
#
#                  region_1      region_2         taster_name  \
# 95               Juliénas           NaN          Roger Voss
# 96                 Régnié           NaN          Roger Voss
# 97           Finger Lakes  Finger Lakes  Anna Lee C. Iijima
# 98  Morellino di Scansano           NaN       Kerin O’Keefe
# 99            Napa Valley          Napa      Virginie Boone
#
#    taster_twitter_handle                                              title  \
# 95            @vossroger                         Henry Fessy 2015  Julienas
# 96            @vossroger                           Henry Fessy 2015  Regnie
# 97                   NaN  Heron Hill 2015 Ingle Vineyard Riesling (Finge...
# 98          @kerinokeefe  Serpaia di Endrizzi 2010 Dono Riserva  (Morell...
# 99               @vboone  Soquel Vineyards 2013 Intreccio Library Select...
#
#                      variety               winery   abv  bottle_size category  \
# 95                     Gamay          Henry Fessy  13.0        750.0      Red
# 96                     Gamay          Henry Fessy  13.0        750.0      Red
# 97                  Riesling           Heron Hill  12.0        750.0    White
# 98                Sangiovese  Serpaia di Endrizzi  14.5        750.0      Red
# 99  Bordeaux-style Red Blend     Soquel Vineyards  14.5        750.0      Red
#
#               importer
# 95    Louis Latour Inc
# 96    Louis Latour Inc
# 97        not_imported
# 98  Artisan Wines, Inc
# 99        not_imported

# %%
for i in range(49000+num, length+1, num):
    odf = df.iloc[i-num:i,:]
    
    odf['page_txt'] = odf.title.apply(lambda x: scrape_page(x))
    if True:
        odf2 = odf.copy(deep=True)
        odf2['abv'] = odf2.page_txt.apply(lambda x: get_abv(x))
        odf2['bottle_size'] = odf2.page_txt.apply(lambda x: get_bottlesize(x))
        odf2['category'] = odf2.page_txt.apply(lambda x: get_category(x))
        odf2['importer'] = odf2.page_txt.apply(lambda x: get_importer(x))
        odf2['importer'] = odf2.importer.apply(lambda x: convert_to_ascii(x))
        
    if 'page_txt' in odf2.columns:
        #print(odf2.columns)
        odf2.drop('page_txt', axis=1, inplace=True)
        
    olddf = pd.read_csv(os.path.join('..','datasets','sectional_scrape.csv'))
    
    odf2 = pd.concat([olddf, odf2], ignore_index=True)

    odf2.to_csv(os.path.join('..','datasets','sectional_scrape.csv'), index=False)
    
    print(i)
# Out:
# C:\Users\Richard Hardis\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400

# %%
if False:
    t1 = time.time()
    df['page_txt'] = df.title.apply(lambda x: scrape_page(x))
    t2 = time.time()
    print('Total time to scrape = {}'.format(t2-t1))

# %%
df.tail()

# %%
df.to_csv(os.path.join('..','datasets','sample_{}_text_only.csv'.format(length)), index=False)

# %%
if False:
    df2 = pd.read_csv(os.path.join('..','datasets','sample_{}_text_only.csv'.format(length)))
    df2['abv'] = df2.page_txt.apply(lambda x: get_abv(x))
    df2['bottle_size'] = df2.page_txt.apply(lambda x: get_bottlesize(x))
    df2['category'] = df2.page_txt.apply(lambda x: get_category(x))
    df2['importer'] = df2.page_txt.apply(lambda x: get_importer(x))
    df2['importer'] = df2.importer.apply(lambda x: convert_to_ascii(x))

if False:
    if 'page_txt' in df2.columns:
        print(df2.columns)
        df2.drop('page_txt', axis=1, inplace=True)

    df2.to_csv(os.path.join('..','datasets','sample_{}.csv'.format(length)))

# %%
# df3 = df2.copy(deep=True)
# df3.dropna(subset=['abv', 'bottle_size', 'category', 'importer'], inplace=True)

# %%
#df3.to_csv(os.path.join('..','datasets','wines_{}_nonan.csv'.format(len(df3))))

# %%
df3 = pd.read_csv(os.path.join('..','datasets','sectional_scrape.csv'))
df3.dropna(subset=['price', 'abv', 'bottle_size', 'category', 'importer'], inplace=True)
df3.to_csv(os.path.join('..','datasets','large_wines_nonan.csv'), index=False)
len(df3)
# Out:
# 73257

# %%
df4 = pd.read_csv(os.path.join('..','datasets','large_wines_nonan.csv'))
len(df4)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Italy  Here's a bright, informal red that opens with ...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 4                             Belsito      87   16.0  Sicily & Sardinia
#
#             region_1           region_2    taster_name taster_twitter_handle  \
# 0               Etna                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN                NaN     Roger Voss            @vossroger
# 2  Willamette Valley  Willamette Valley   Paul Gregutt           @paulgwine
# 3  Willamette Valley  Willamette Valley   Paul Gregutt           @paulgwine
# 4           Vittoria                NaN  Kerin O’Keefe          @kerinokeefe
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulka Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# 4   Terre di Giurfo 2013 Belsito Frappato (Vittoria)        Frappato
#
#                 winery   abv  bottle_size category  \
# 0              Nicosia  12.5        750.0    White
# 1  Quinta dos Avidagos  13.0        750.0      Red
# 2            Rainstorm  12.5        750.0    White
# 3         Sweet Cheeks  13.5        750.0      Red
# 4      Terre di Giurfo  13.5        750.0      Red
#
#                       importer
# 0           1_No Submitting Co
# 1  San Francisco Wine Exchange
# 2                 not_imported
# 3                 not_imported
# 4               Wirtz Beverage

# %%
def get_year(s):
    matches = re.findall(r'\d\d\d\d',s)
    if matches:
        return matches[0]
    else:
        return None
    
df4['year'] = df4['title'].apply(lambda x: get_year(x))
df4.dropna(subset=['year'], inplace=True)
print('year processed')
